# %% [markdown]
# <a href="https://colab.research.google.com/github/vimalgits/python/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are so many libraries, frameworks, and tools that are used for the task of web scraping. Some of the most common libraries and modules in Python used for web scraping are:
#
# 1.Scrapy
# 2.Selenium
# 3.BeautifulSoup
# 4.Urlib.request
# All of the above Python libraries and modules are great for scraping data from websites. After scraping the data, the data is prepared so that it can be stored in a CSV file to create a dataset.

# %% [markdown]
#  For this task, I will be using the BeautifulSoup library in Python. Here I am going to search for a random term on Google and then I will collect the data from the very first page that Google shows me.
#
# So, I searched for “comparison of programming languages” on Google and got this article as the first result. Let’s see how we can scrape data from this web page to create a dataset. Below is how we can use the BeautifulSoup library in Python for the task of web scraping to create a dataset:

# %%
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen("https://en.wikipedia.org/wiki/Comparison_of_programming_languages")
soup = BeautifulSoup(html, "html.parser")
table = soup.findAll("table", {"class":"wikitable"})[0]
rows = table.findAll("tr")

with open("language.csv", "wt+", newline="") as f:
    writer = csv.writer(f)
    for i in rows:
        row = []
        for cell in i.findAll(["td", "th"]):
            row.append(cell.get_text())
        writer.writerow(row)
   
  
import pandas as pd
a = pd.read_csv("language.csv")
a.head(20)
# Out:
#                               Language\n  \
# 0   1C:Enterprise programming language\n
# 1                         ActionScript\n
# 2                                  Ada\n
# 3                                Aldor\n
# 4                             ALGOL 58\n
# 5                             ALGOL 60\n
# 6                             ALGOL 68\n
# 7                             Ateji PX\n
# 8                                  APL\n
# 9                    Assembly language\n
# 10                          AutoHotkey\n
# 11                              AutoIt\n
# 12                           Ballerina\n
# 13                                Bash\n
# 14                               BASIC\n
# 15                           BeanShell\n
# 16                               BLISS\n
# 17                            BlitzMax\n
# 18                                 Boo\n
# 19                                   C\n
#
#                                    Original purpose\n Imperative\n  \
# 0   Application, RAD, business, general, web, mobi...        Yes\n
# 1                     Application, client-side, web\n        Yes\n
# 2           Application, embedded, realtime, system\n        Yes\n
# 3        Highly domain-specific, symbolic computing\n        Yes\n
# 4                                       Application\n        Yes\n
# 5                                       Application\n        Yes\n
# 6                                       Application\n        Yes\n
# 7                              Parallel application\n         No\n
# 8                      Application, data processing\n        Yes\n
# 9                                           General\n        Yes\n
# 10  GUI automation (macros), highly domain-specific\n        Yes\n
# 11  GUI automation (macros), highly domain-specific\n        Yes\n
# 12         Integration, agile, server-side, general\n        Yes\n
# 13                                 Shell, scripting\n        Yes\n
# 14                           Application, education\n        Yes\n
# 15                           Application, scripting\n        Yes\n
# 16                                           System\n         No\n
# 17                                Application, game\n        Yes\n
# 18                      Application, game scripting\n         No\n
# 19  Application, system,[15] general purpose, low-...        Yes\n
#
#    Object-oriented\n Functional\n Procedural\n Generic\n Reflective\n  \
# 0               No\n        Yes\n        Yes\n     Yes\n        Yes\n
# 1              Yes\n        Yes\n        Yes\n      No\n         No\n
# 2           Yes[2]\n         No\n     Yes[3]\n  Yes[4]\n         No\n
# 3              Yes\n        Yes\n         No\n      No\n         No\n
# 4               No\n         No\n         No\n      No\n         No\n
# 5               No\n         No\n        Yes\n     Yes\n         No\n
# 6               No\n        Yes\n        Yes\n     Yes\n         No\n
# 7              Yes\n         No\n         No\n      No\n         No\n
# 8              Yes\n        Yes\n        Yes\n     Yes\n        Yes\n
# 9               No\n         No\n         No\n      No\n         No\n
# 10         Yes[11]\n         No\n        Yes\n      No\n         No\n
# 11              No\n         No\n        Yes\n      No\n         No\n
# 12             Yes\n        Yes\n        Yes\n      No\n         No\n
# 13              No\n         No\n        Yes\n      No\n         No\n
# 14              No\n         No\n        Yes\n      No\n         No\n
# 15             Yes\n        Yes\n         No\n      No\n        Yes\n
# 16              No\n         No\n        Yes\n      No\n         No\n
# 17             Yes\n         No\n        Yes\n      No\n        Yes\n
# 18             Yes\n         No\n         No\n      No\n         No\n
# 19              No\n         No\n        Yes\n      No\n         No\n
#
#    Event-driven\n                                  Other paradigms\n  \
# 0           Yes\n        Object-based, Prototype-based programming\n
# 1           Yes\n                                  prototype-based\n
# 2            No\n                   Concurrent,[5] distributed,[6]\n
# 3            No\n                                                 \n
# 4            No\n                                                 \n
# 5            No\n                                                 \n
# 6            No\n                                       Concurrent\n
# 7            No\n                                      pi calculus\n
# 8           Yes\n                            Array-oriented, tacit\n
# 9            No\n  Any, syntax is usually highly specific, relate...
# 10          Yes\n                                                 \n
# 11          Yes\n                                                 \n
# 12          Yes\n  Concurrent, transactional, statically and stro...
# 13           No\n                                                 \n
# 14           No\n                                                 \n
# 15           No\n                                                 \n
# 16           No\n                                                 \n
# 17           No\n                                                 \n
# 18           No\n                                                 \n
# 19           No\n                                                 \n
#
#                                       Standardized?\n
# 0                                                No\n
# 1   Yes1999-2003, ActionScript 1.0 with ES3, Actio...
# 2   Yes1983, 2005, 2012, ANSI, ISO, GOST 27831-88[...
# 3                                                No\n
# 4                                                No\n
# 5                      Yes1960, IFIP WG 2.1, ISO[8]\n
# 6           Yes1968, IFIP WG 2.1, GOST 27974-88,[9]\n
# 7                                                No\n
# 8                                      Yes1989, ISO\n
# 9                         Yes1985 IEEE 694-1985[10]\n
# 10                                               No\n
# 11                                               No\n
# 12  De factostandard via Ballerina Language Specif...
# 13                            OptionallyPOSIX.2[13]\n
# 14                         Yes1983, ANSI, ISO, ECMA\n
# 15                           NoIn progress, JCP[14]\n
# 16                                               No\n
# 17                                               No\n
# 18                                               No\n
# 19  Yes1989, ANSI C89, ISO/IEC C90, ISO/IEC C95, I...
